# %%
# https://www.blog.datahut.co/post/scraping-amazon-best-seller-data-using-python
# links for proxies: https://www.zenrows.com/blog/selenium-proxy#proxy-authentication

# Importing libraries
import time
import random
import pandas as pd
from bs4 import BeautifulSoup
from selenium import webdriver
pd.options.mode.chained_assignment = None
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
# from selenium.webdriver.chrome import ChromeDriverManager
from selenium.webdriver.chrome.service import Service

from selenium.webdriver.chrome.options import Options

from selenium.webdriver.chrome.service import Service as ChromeService
from webdriver_manager.chrome import ChromeDriverManager

# %%
# Function to delay some process
def delay():
    # time.sleep(random.randint(1, 3))
    time.sleep(2)

# Scrolling down the page in order to overcome Lazy Loading
def lazy_loading():
    element = driver.find_element(By.TAG_NAME, 'body')
    count = 0
    while count < 20:
        element.send_keys(Keys.PAGE_DOWN)
        delay()
        count += 1

# Function to fetch the product links of products
def fetch_product_links_and_ranks():
    content = driver.page_source
    homepage_soup = BeautifulSoup(content, 'html.parser')

    all_products = homepage_soup.find('div', attrs={"class": "p13n-desktop-grid"})
    for product_section in all_products.find_all('div', {'id': 'gridItemRoot'}):
        for product_link in product_section.find_all('a',{'tabindex':'-1'}):
            # count = 1
            # if count > 2:
            if product_link['href'].startswith('https:'):
                product_links.append(product_link['href'])
            else:
                product_links.append('https://www.amazon.com' + product_link['href'])
            print(product_link['href'])
                # count += 1
        ranking.append(product_section.find('span',{'class': 'zg-bdg-text'}).text)

# Function to extract content of the page
def extract_content(url):
    driver.get(url)
    page_content = driver.page_source
    product_soup = BeautifulSoup(page_content, 'html.parser')
    return product_soup

# Function to extract product name
def extract_product_name(soup):
    try:
        name_of_product = soup.find('div', attrs={"id": "titleSection"}).text.strip()
        data['product name'].iloc[product] = name_of_product

    except:
        name_of_product = 'Product name not available '
        data['product name'].iloc[product] = name_of_product

# Function to extract brand name
def extract_brand(soup):
    try:
        brand = soup.find('a', attrs={"id": "bylineInfo"}).text.split(':')[1].strip()  #one location where brand data could be found
        data['brand'].iloc[product] = brand

    except:
        if soup.find_all('tr', attrs={'class': 'a-spacing-small po-brand'}):  #other location where brand data could be found
            brand = soup.find_all('tr', attrs={'class': 'a-spacing-small po-brand'})[0].text.strip().split(' ')[-1]
            data['brand'].iloc[product] = brand
        else:
            brand = 'Brand data not available'
            data['brand'].iloc[product] = brand

# Function to extract price
def extract_price(soup):
    try:
        price = soup.find('span', attrs={"class": "a-price a-text-price a-size-medium apexPriceToPay"}).text.split('$')[
            -1]
        data['price(in dollar)'].iloc[product] = price

    except:
        price = 'Price data not available'
        data['price(in dollar)'].iloc[product] = price

# Function to extract size
def extract_size(soup):
    try:
        size = soup.find('span', attrs={"id": "inline-twister-expanded-dimension-text-size_name"}).text.strip()
        data['size'].iloc[product] = size

    except:
        size = 'Size data not available'
        data['size'].iloc[product] = size

# Function to extract star rating
def extract_star_rating(soup):
    try:
        star = None
        for star_rating_locations in ['a-icon a-icon-star a-star-4-5', 'a-icon a-icon-star a-star-5']:
            stars = soup.find_all('i', attrs={"class": star_rating_locations})
            for i in range(len(stars)):
                star = stars[i].text.split(' ')[0]
                if star:
                    break
            if star:
                break
        
    except:
        star = 'Star rating data not available'
        
    data['star rating'].iloc[product] = star  

# Function to extract number of ratings
def extract_num_of_ratings(soup):
    try:
        star = soup.find('span', attrs={"id": "acrCustomerReviewText"}).text.split(' ')[0]
        data['number of ratings'].iloc[product] = star

    except:
        star = 'Number of rating not available'
        data['number of ratings'].iloc[product] = star

# Function to extract color
def extract_color(soup):
    try:
        color = soup.find('tr', attrs={'class': 'a-spacing-small po-color'}).text.strip().split('  ')[1].strip()
        data['color'].iloc[product] = color

    except:
        color = 'Color not available'
        data['color'].iloc[product] = color

# Function to extract hardware interface
def extract_hardware_interface(soup):
    try:
        hardware_interface = \
        soup.find('tr', attrs={"class": "a-spacing-small po-hardware_interface"}).text.strip().split('  ')[1].strip()
        data['hardware interface'].iloc[product] = hardware_interface

    except:
        hardware_interface = 'Hardware interface data not available'
        data['hardware interface'].iloc[product] = hardware_interface

# Function to extract compatible devices
def extract_compatible_devices(soup):
    try:
        compatible_devices = \
        soup.find('tr', attrs={"class": "a-spacing-small po-compatible_devices"}).text.strip().split('  ')[1].strip()
        data['compatible devices'].iloc[product] = compatible_devices

    except:
        compatible_devices = 'Compatible devices data not available'
        data['compatible devices'].iloc[product] = compatible_devices

# Function to extract data transfer rate
def extract_data_transfer_rate(soup):
    try:
        data_transfer_rate = \
        soup.find('tr', attrs={"class": "a-spacing-small po-data_transfer_rate"}).text.strip().split('  ')[1].strip()
        data['data transfer rate'].iloc[product] = data_transfer_rate

    except:
        data_transfer_rate = 'Data transfer rate data not available'
        data['data transfer rate'].iloc[product] = data_transfer_rate

# Function to extract mounting type
def extract_mounting_type(soup):
    try:
        mounting_type = soup.find('tr', attrs={"class": "a-spacing-small po-mounting_type"}).text.strip().split('  ')[
            1].strip()
        data['mounting type'].iloc[product] = mounting_type

    except:
        mounting_type = 'Mounting type data not available'
        data['mounting type'].iloc[product] = mounting_type

# Function to extract special features
def extract_special_features(soup):
    try:
        special_feature = \
        soup.find('tr', attrs={"class": "a-spacing-small po-special_feature"}).text.strip().split('  ')[1].strip()
        data['special features'].iloc[product] = special_feature

    except:
        special_feature = 'Special features data not available'
        data['special features'].iloc[product] = special_feature



# Function to extract connectivity technology
def extract_connectivity_technology(soup):
    try:
        connectivity_technology = \
        soup.find('tr', attrs={"class": "a-spacing-small po-connectivity_technology"}).text.strip().split('  ')[
            1].strip()
        data['connectivity technology'].iloc[product] = connectivity_technology

    except:
        connectivity_technology = 'Connectivity technology data not available'
        data['connectivity technology'].iloc[product] = connectivity_technology


# Function to extract connector type
def extract_connector_type(soup):
    try:
        connector_type = soup.find('tr', attrs={"class": "a-spacing-small po-connector_type"}).text.strip().split('  ')[
            1].strip()
        data['connector type'].iloc[product] = connector_type

    except:
        connector_type = 'Connector type data not available'
        data['connector type'].iloc[product] = connector_type

# Function to extract date first available
def extract_date_first_available(soup):
    try:
        product_details_keys = soup.find_all('th', attrs={"class": "a-color-secondary a-size-base prodDetSectionEntry"})
        product_details_values = soup.find_all('td', attrs={"class": "a-size-base prodDetAttrValue"})
        for detail_key in range(len(product_details_keys)):
            if 'Date First Available' in product_details_keys[detail_key].text:
                date_first_available = product_details_values[detail_key - 2].text
                if '20' not in date_first_available:
                    date_first_available = product_details_values[detail_key].text
        data['date first available'].iloc[product] = date_first_available

    except:
        date_first_available = 'Date first available data not available'
        data['date first available'].iloc[product] = date_first_available

# driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()))
driver = webdriver.Chrome()

# Fetching the product links of all items
product_links = []
ranking=[]

for page in range(1,3):               # to iterate over the 2 pages in which the products are divided into
    # start_url = f'https://www.amazon.com/Best-Sellers-Computers-Accessories/zgbs/pc/ref=zg_bs_pg_{page}?_encoding=UTF8&pg={page}'
    start_url = f'https://www.amazon.com.mx/gp/bestsellers/books/ref=zg_bs_pg_{page}_books?ie=UTF8&pg={page}'
    driver.get(start_url)
    print("Scrapping main", start_url)
    lazy_loading()                     # to overcome lazy loading
    fetch_product_links_and_ranks()    # to fetch the links to products 

# Creating a dictionary of the required columns
data_dic = {'product url': [],'ranking': [], 'brand': [], 'product name': [],
            'number of ratings': [], 'size': [], 'star rating': [], 'price(in dollar)': [], 'color': [],
            'hardware interface': [], 'compatible devices': [], 'connectivity technology': [], 'connector type': [], 'data transfer rate':[], 'mounting type': [], 'special features':[], 'date first available':[]}


# # Creating a data frame with those columns
# data = pd.DataFrame(data_dic)


# # Assigning the scraped links and rankings to the columns 'product url' and 'ranking'
# data['product url'] = product_links
# data['ranking'] = ranking

# for product in range(len(data)):
#     product_url = data['product url'].iloc[product]
#     product_content = extract_content(product_url)

#     # brands
#     extract_brand(product_content)

#     # product_name
#     extract_product_name(product_content)

#     # price
#     extract_price(product_content)

#     # size
#     extract_size(product_content)

#     # star rating
#     extract_star_rating(product_content)

#     # number of ratings
#     extract_num_of_ratings(product_content)

#     # color
#     extract_color(product_content)

#     # hardware interface
#     extract_hardware_interface(product_content)

#     # compatible devices
#     extract_compatible_devices(product_content)

#     # data transfer rate
#     extract_data_transfer_rate(product_content)

#     # mounting type
#     extract_mounting_type(product_content)

#     # special features
#     extract_special_features(product_content)

#     # connectivity technology
#     extract_connectivity_technology(product_content)

#     # connector type
#     extract_connector_type(product_content)

#     # date first available
#     extract_date_first_available(product_content)

# # saving the resultant data frame as a csv file
# data.to_csv('amazon_best_sellers.csv')
# Out:
# Scrapping main https://www.amazon.com.mx/gp/bestsellers/books/ref=zg_bs_pg_1_books?ie=UTF8&pg=1
# ---------------------------------------------------------------------------
# NoSuchWindowException                     Traceback (most recent call last)
# Cell In[5], line 232
#     230     driver.get(start_url)
#     231     print("Scrapping main", start_url)
# --> 232     lazy_loading()                     # to overcome lazy loading
#     233     fetch_product_links_and_ranks()    # to fetch the links to products
#     235 # Creating a dictionary of the required columns
#
# Cell In[5], line 11, in lazy_loading()
#       9 count = 0
#      10 while count < 20:
# ---> 11     element.send_keys(Keys.PAGE_DOWN)
#      12     delay()
#      13     count += 1
#
# File c:\Users\j50022283\AppData\Local\Programs\Python\Python310\lib\site-packages\selenium\webdriver\remote\webelement.py:231, in WebElement.send_keys(self, *value)
#     228             remote_files.append(self._upload(file))
#     229         value = "\n".join(remote_files)
# --> 231 self._execute(
#     232     Command.SEND_KEYS_TO_ELEMENT, {"text": "".join(keys_to_typing(value)), "value": keys_to_typing(value)}
#     233 )
#
# File c:\Users\j50022283\AppData\Local\Programs\Python\Python310\lib\site-packages\selenium\webdriver\remote\webelement.py:395, in WebElement._execute(self, command, params)
#     393     params = {}
#     394 params["id"] = self._id
# --> 395 return self._parent.execute(command, params)
#
# File c:\Users\j50022283\AppData\Local\Programs\Python\Python310\lib\site-packages\selenium\webdriver\remote\webdriver.py:345, in WebDriver.execute(self, driver_command, params)
#     343 response = self.command_executor.execute(driver_command, params)
#     344 if response:
# --> 345     self.error_handler.check_response(response)
#     346     response["value"] = self._unwrap_value(response.get("value", None))
#     347     return response
#
# File c:\Users\j50022283\AppData\Local\Programs\Python\Python310\lib\site-packages\selenium\webdriver\remote\errorhandler.py:229, in ErrorHandler.check_response(self, response)
#     227         alert_text = value["alert"].get("text")
#     228     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 229 raise exception_class(message, screen, stacktrace)
#
# NoSuchWindowException: Message: no such window: target window already closed
# from unknown error: web view not found
#   (Session info: chrome=115.0.5790.171)
# Stacktrace:
# Backtrace:
# 	GetHandleVerifier [0x00007FF715624A62+57106]
# 	(No symbol) [0x00007FF71559CF52]
# 	(No symbol) [0x00007FF71546E2CB]
# 	(No symbol) [0x00007FF71544DEB9]
# 	(No symbol) [0x00007FF7154CAE07]
# 	(No symbol) [0x00007FF7154DDBEF]
# 	(No symbol) [0x00007FF7154C6793]
# 	(No symbol) [0x00007FF71549CE81]
# 	(No symbol) [0x00007FF71549E064]
# 	GetHandleVerifier [0x00007FF7158D4222+2873042]
# 	GetHandleVerifier [0x00007FF715926590+3209792]
# 	GetHandleVerifier [0x00007FF71591F3AF+3180639]
# 	GetHandleVerifier [0x00007FF7156B5F25+652245]
# 	(No symbol) [0x00007FF7155A8618]
# 	(No symbol) [0x00007FF7155A47C4]
# 	(No symbol) [0x00007FF7155A48BC]
# 	(No symbol) [0x00007FF715594C33]
# 	BaseThreadInitThunk [0x00007FF832257614+20]
# 	RtlUserThreadStart [0x00007FF832F626F1+33]

# %%
print(data)
# Out:
#                                           product url ranking  \
# 0   https://www.amazon.com/H%C3%A1bitos-At%C3%B3mi...      #1
# 1   https://www.amazon.com/El-Principito-Antoine-S...      #2
# 2   https://www.amazon.com/Identifica-resuelve-tra...      #3
# 3   https://www.amazon.com/Fisco-Agenda-2023-Sin-a...      #4
# 4   https://www.amazon.com/revoluci%C3%B3n-glucosa...      #5
# ..                                                ...     ...
# 95  https://www.amazon.com/Am-Simba-Disney-Lion-Ki...     #96
# 96  https://www.amazon.com/Vivir-las-Fibras-modelo...     #97
# 97  https://www.amazon.com/Diccionario-b%C3%A1sico...     #98
# 98  https://www.amazon.com/Netter-Cuaderno-fisiolo...     #99
# 99  https://www.amazon.com/hay-verano-sin-Jenny-Ha...    #100
#
#                        brand                 product name  \
# 0   Brand data not available  Product name not available
# 1   Brand data not available  Product name not available
# 2   Brand data not available  Product name not available
# 3   Brand data not available  Product name not available
# 4   Brand data not available  Product name not available
# ..                       ...                          ...
# 95  Brand data not available  Product name not available
# 96  Brand data not available  Product name not available
# 97  Brand data not available  Product name not available
# 98  Brand data not available  Product name not available
# 99  Brand data not available  Product name not available
#
#                  number of ratings                     size star rating  \
# 0   Number of rating not available  Size data not available         NaN
# 1                            8,374  Size data not available         NaN
# 2                            3,952  Size data not available
# 3                               95  Size data not available        None
# 4                            1,788  Size data not available
# ..                             ...                      ...         ...
# 95                           1,383  Size data not available
# 96                             548  Size data not available
# 97                             297  Size data not available        None
# 98                             127  Size data not available
# 99                              30  Size data not available
#
#             price(in dollar)                color  \
# 0   Price data not available  Color not available
# 1   Price data not available  Color not available
# 2   Price data not available  Color not available
# 3   Price data not available  Color not available
# 4   Price data not available  Color not available
# ..                       ...                  ...
# 95  Price data not available  Color not available
# 96  Price data not available  Color not available
# 97  Price data not available  Color not available
# 98  Price data not available  Color not available
# 99  Price data not available  Color not available
#
#                        hardware interface  \
# 0   Hardware interface data not available
# 1   Hardware interface data not available
# 2   Hardware interface data not available
# 3   Hardware interface data not available
# 4   Hardware interface data not available
# ..                                    ...
# 95  Hardware interface data not available
# 96  Hardware interface data not available
# 97  Hardware interface data not available
# 98  Hardware interface data not available
# 99  Hardware interface data not available
#
#                        compatible devices  \
# 0   Compatible devices data not available
# 1   Compatible devices data not available
# 2   Compatible devices data not available
# 3   Compatible devices data not available
# 4   Compatible devices data not available
# ..                                    ...
# 95  Compatible devices data not available
# 96  Compatible devices data not available
# 97  Compatible devices data not available
# 98  Compatible devices data not available
# 99  Compatible devices data not available
#
#                        connectivity technology  \
# 0   Connectivity technology data not available
# 1   Connectivity technology data not available
# 2   Connectivity technology data not available
# 3   Connectivity technology data not available
# 4   Connectivity technology data not available
# ..                                         ...
# 95  Connectivity technology data not available
# 96  Connectivity technology data not available
# 97  Connectivity technology data not available
# 98  Connectivity technology data not available
# 99  Connectivity technology data not available
#
#                        connector type                     data transfer rate  \
# 0   Connector type data not available  Data transfer rate data not available
# 1   Connector type data not available  Data transfer rate data not available
# 2   Connector type data not available  Data transfer rate data not available
# 3   Connector type data not available  Data transfer rate data not available
# 4   Connector type data not available  Data transfer rate data not available
# ..                                ...                                    ...
# 95  Connector type data not available  Data transfer rate data not available
# 96  Connector type data not available  Data transfer rate data not available
# 97  Connector type data not available  Data transfer rate data not available
# 98  Connector type data not available  Data transfer rate data not available
# 99  Connector type data not available  Data transfer rate data not available
#
#                        mounting type                     special features  \
# 0   Mounting type data not available  Special features data not available
# 1   Mounting type data not available  Special features data not available
# 2   Mounting type data not available  Special features data not available
# 3   Mounting type data not available  Special features data not available
# 4   Mounting type data not available  Special features data not available
# ..                               ...                                  ...
# 95  Mounting type data not available  Special features data not available
# 96  Mounting type data not available  Special features data not available
# 97  Mounting type data not available  Special features data not available
# 98  Mounting type data not available  Special features data not available
# 99  Mounting type data not available  Special features data not available
#
#                        date first available
# 0   Date first available data not available
# 1   Date first available data not available
# 2   Date first available data not available
# 3   Date first available data not available
# 4   Date first available data not available
# ..                                      ...
# 95  Date first available data not available
# 96  Date first available data not available
# 97  Date first available data not available
# 98  Date first available data not available
# 99  Date first available data not available
#
# [100 rows x 17 columns]

# %%
links_dic = {'number': [],'product_url': [],'already_scrapped':[]}


# Creating a data frame with those columns
data_links = pd.DataFrame(links_dic)


# Assigning the scraped links and rankings to the columns 'product url' and 'ranking'
data_links['number'] = range(0, len(product_links))
data_links['product_url'] = product_links
data_links['already_scrapped'] = "no"


# saving the resultant data frame as a csv file
data_links.to_csv('links_amazon.csv', index=False)

# %%
df = pd.read_csv ('links_amazon.csv')
# print(df)

# select_row = df.loc[df['number'] == 10]
# print (select_row['product_url'])

select_row = df['product_url']
print (list(select_row))
# Out:
# ['https://www.amazon.com/H%C3%A1bitos-At%C3%B3micos-James-Clear/dp/6077476714/ref=zg_bs_g_books_sccl_1/146-3411080-7998212?psc=1', 'https://www.amazon.com/El-Principito-Antoine-Saint-Exup%C3%A9ry/dp/6076189495/ref=zg_bs_g_books_sccl_2/146-3411080-7998212?psc=1', 'https://www.amazon.com/Identifica-resuelve-traumas-familiares-heredados/dp/8484456811/ref=zg_bs_g_books_sccl_3/146-3411080-7998212?psc=1', 'https://www.amazon.com/Fisco-Agenda-2023-Sin-autor/dp/6075413758/ref=zg_bs_g_books_sccl_4/146-3411080-7998212?psc=1', 'https://www.amazon.com/revoluci%C3%B3n-glucosa-Jessie-Inchausp%C3%A9/dp/6070790510/ref=zg_bs_g_books_sccl_5/146-3411080-7998212?psc=1', 'https://www.amazon.com/Viajar-cambiar%C3%A1-vida-Alan-Estrada/dp/6070748514/ref=zg_bs_g_books_sccl_6/146-3411080-7998212?psc=1', 'https://www.amazon.com/Beyond-Story-Cr%C3%B3nica-a%C3%B1os-BTS/dp/607383490X/ref=zg_bs_g_books_sccl_7/146-3411080-7998212?psc=1', 'https://www.amazon.com/El-dinosaurio-disfrazado-Macario-Schettino/dp/607569532X/ref=zg_bs_g_books_sccl_8/146-3411080-7998212?psc=1', 'https://www.amazon.com/Hay-T-rex-ciudad-Mega-Ediciones/dp/6072107788/ref=zg_bs_g_books_sccl_9/146-3411080-7998212?psc=1', 'https://www.amazon.com/Cosas-que-nunca-habl%C3%A9-madre/dp/6070771583/ref=zg_bs_g_books_sccl_10/146-3411080-7998212?psc=1', 'https://www.amazon.com/Patrol-Jumbo-Graciela-Iniesta-Ram%C3%ADrez/dp/607212352X/ref=zg_bs_g_books_sccl_11/146-3411080-7998212?psc=1', 'https://www.amazon.com/Diccionario-escolar-plus-primaria-Ignacio/dp/607210004X/ref=zg_bs_g_books_sccl_12/146-3411080-7998212?psc=1', 'https://www.amazon.com/Deja-Ser-Tu-Joe-Dispenza/dp/6079344084/ref=zg_bs_g_books_sccl_13/146-3411080-7998212?psc=1', 'https://www.amazon.com/Descubre-mejores-amigos-Garc%C3%ADa-Cerezo/dp/6072128947/ref=zg_bs_g_books_sccl_14/146-3411080-7998212?psc=1', 'https://www.amazon.com/hacer-pasen-cosas-buenas-Edici%C3%B3n/dp/6073903359/ref=zg_bs_g_books_sccl_15/146-3411080-7998212?psc=1', 'https://www.amazon.com/ganar-amigos-influir-sobre-personas/dp/6073155719/ref=zg_bs_g_books_sccl_16/146-3411080-7998212?psc=1', 'https://www.amazon.com/biblioteca-media-noche-Matt-Haig/dp/607550771X/ref=zg_bs_g_books_sccl_17/146-3411080-7998212?psc=1', 'https://www.amazon.com/Encuentra-persona-vitamina-Marian-Estap%C3%A9/dp/6070780361/ref=zg_bs_g_books_sccl_18/146-3411080-7998212?psc=1', 'https://www.amazon.com/Mandalas-Nueva-Imagen/dp/6077441473/ref=zg_bs_g_books_sccl_19/146-3411080-7998212?psc=1', 'https://www.amazon.com/Larousse-Diccionario-Pocket-Espanol-Ingles-Ingles-Espanol/dp/9706074937/ref=zg_bs_g_books_sccl_20/146-3411080-7998212?psc=1', 'https://www.amazon.com/sutil-arte-que-importe-carajo/dp/6078589172/ref=zg_bs_g_books_sccl_21/146-3411080-7998212?psc=1', 'https://www.amazon.com/My-Dress-Up-Darling-N-8-Editorial/dp/B0CC425QKF/ref=zg_bs_g_books_sccl_22/146-3411080-7998212?psc=1', 'https://www.amazon.com/Psychology-Money-Timeless-Lessons-Happiness/dp/0857197681/ref=zg_bs_g_books_sccl_23/146-3411080-7998212?psc=1', 'https://www.amazon.com/Las-48-leyes-del-poder/dp/6075276912/ref=zg_bs_g_books_sccl_24/146-3411080-7998212?psc=1', 'https://www.amazon.com/Meditaciones-Marco-Aurelio/dp/6073812450/ref=zg_bs_g_books_sccl_25/146-3411080-7998212?psc=1', 'https://www.amazon.com/Muchas-vidas-muchos-maestros-Brian/dp/6073175655/ref=zg_bs_g_books_sccl_26/146-3411080-7998212?psc=1', 'https://www.amazon.com/Transforma-las-heridas-infancia-humullaci%C3%B3n/dp/6073173814/ref=zg_bs_g_books_sccl_27/146-3411080-7998212?psc=1', 'https://www.amazon.com/Complete-Summer-Turned-Pretty-Trilogy/dp/1442498323/ref=zg_bs_g_books_sccl_28/146-3411080-7998212?psc=1', 'https://www.amazon.com/Diccionario-pocket-franc%C3%A9s-Editorial-Larousse/dp/9702202159/ref=zg_bs_g_books_sccl_29/146-3411080-7998212?psc=1', 'https://www.amazon.com/Disney-Baby-Biblioteca-personajes-Incre%C3%ADbles/dp/1503733378/ref=zg_bs_g_books_sccl_30/146-3411080-7998212?psc=1', 'https://www.amazon.com/Small-Premium-Sketchbook-Peter-Pauper/dp/1441310215/ref=zg_bs_g_boo ...

# %%
driver = webdriver.Chrome()
for url in select_row:
    
    driver.get(url)
    page_content = driver.page_source
    soup = BeautifulSoup(page_content, 'html.parser')
    

    print(url)

    try:
        name_of_product = soup.find('span', attrs={"id": "productTitle"}).text.strip()
        print(name_of_product)

    except:
        name_of_product = 'Product name not available '
        print(name_of_product)

    try:
        description_of_product = soup.find('div', attrs={"class": "a-expander-content a-expander-partial-collapse-content"})
        description_of_product = description_of_product.find_all('span')
        print(description_of_product)

    except:
        description_of_product = 'desc name not available '
        print(description_of_product)
# Out:
# https://www.amazon.com/H%C3%A1bitos-At%C3%B3micos-James-Clear/dp/6077476714/ref=zg_bs_g_books_sccl_1/146-3411080-7998212?psc=1
# Product name not available
# desc name not available
# https://www.amazon.com/El-Principito-Antoine-Saint-Exup%C3%A9ry/dp/6076189495/ref=zg_bs_g_books_sccl_2/146-3411080-7998212?psc=1
# Product name not available
# desc name not available
# https://www.amazon.com/Identifica-resuelve-traumas-familiares-heredados/dp/8484456811/ref=zg_bs_g_books_sccl_3/146-3411080-7998212?psc=1
# Product name not available
# desc name not available
# https://www.amazon.com/Fisco-Agenda-2023-Sin-autor/dp/6075413758/ref=zg_bs_g_books_sccl_4/146-3411080-7998212?psc=1
# Product name not available
# desc name not available
# https://www.amazon.com/revoluci%C3%B3n-glucosa-Jessie-Inchausp%C3%A9/dp/6070790510/ref=zg_bs_g_books_sccl_5/146-3411080-7998212?psc=1
# Product name not available
# desc name not available
# https://www.amazon.com/Viajar-cambiar%C3%A1-vida-Alan-Estrada/dp/6070748514/ref=zg_bs_g_books_sccl_6/146-3411080-7998212?psc=1
# Product name not available
# desc name not available
# https://www.amazon.com/Beyond-Story-Cr%C3%B3nica-a%C3%B1os-BTS/dp/607383490X/ref=zg_bs_g_books_sccl_7/146-3411080-7998212?psc=1
# Product name not available
# desc name not available
# https://www.amazon.com/El-dinosaurio-disfrazado-Macario-Schettino/dp/607569532X/ref=zg_bs_g_books_sccl_8/146-3411080-7998212?psc=1
# Product name not available
# desc name not available
# https://www.amazon.com/Hay-T-rex-ciudad-Mega-Ediciones/dp/6072107788/ref=zg_bs_g_books_sccl_9/146-3411080-7998212?psc=1
# Product name not available
# desc name not available
# https://www.amazon.com/Cosas-que-nunca-habl%C3%A9-madre/dp/6070771583/ref=zg_bs_g_books_sccl_10/146-3411080-7998212?psc=1
# Product name not available
# desc name not available
# https://www.amazon.com/Patrol-Jumbo-Graciela-Iniesta-Ram%C3%ADrez/dp/607212352X/ref=zg_bs_g_books_sccl_11/146-3411080-7998212?psc=1
# Product name not available
# desc name not available
# https://www.amazon.com/Diccionario-escolar-plus-primaria-Ignacio/dp/607210004X/ref=zg_bs_g_books_sccl_12/146-3411080-7998212?psc=1
# Product name not available
# desc name not available
# https://www.amazon.com/Deja-Ser-Tu-Joe-Dispenza/dp/6079344084/ref=zg_bs_g_books_sccl_13/146-3411080-7998212?psc=1
# Product name not available
# desc name not available
# https://www.amazon.com/Descubre-mejores-amigos-Garc%C3%ADa-Cerezo/dp/6072128947/ref=zg_bs_g_books_sccl_14/146-3411080-7998212?psc=1
# Product name not available
# desc name not available
# https://www.amazon.com/hacer-pasen-cosas-buenas-Edici%C3%B3n/dp/6073903359/ref=zg_bs_g_books_sccl_15/146-3411080-7998212?psc=1
# Product name not available
# desc name not available
# https://www.amazon.com/ganar-amigos-influir-sobre-personas/dp/6073155719/ref=zg_bs_g_books_sccl_16/146-3411080-7998212?psc=1
# Product name not available
# desc name not available
# https://www.amazon.com/biblioteca-media-noche-Matt-Haig/dp/607550771X/ref=zg_bs_g_books_sccl_17/146-3411080-7998212?psc=1
# Product name not available
# desc name not available
# https://www.amazon.com/Encuentra-persona-vitamina-Marian-Estap%C3%A9/dp/6070780361/ref=zg_bs_g_books_sccl_18/146-3411080-7998212?psc=1
# Encuentra tu persona vitamina (Spanish Edition)
# [<span class="a-text-bold">¿Por qué hay personas que nos hacen sufrir tanto y otras que nos generan confianza y cuya sola presencia nos reconforta? ¿Por qué hay gente que tiene tendencia a establecer relaciones complicadas y dolorosas? ¿Amamos como nos amaron? ¿Hay «algo» bioquímico detrás de la confianza, el apego y el amor? ¿Cómo podemos acertar a la hora de elegir pareja? </span>, <span> Estamos diseñados para vivir en familia y en sociedad, relacionarnos y querernos. Nuestra felicidad va a depender en gran medida de la capacidad que tengamos para mantener buenas relaciones con aquellos que nos rodean. Muchos, hoy en día, arrastramos heridas emocionales que nos impiden conectar de forma sana con el entorno. Encuentra tu persona vitamina te ayudará a comprender el vínculo con tus padres, tus hijos, tu pareja, tus amigos y tus compañeros de trabajo a la vez que entiendes tu historia emocional. Porque cuando uno se comprende, se siente aliviado. La doctora Marian Rojas Estapé te acerca al apego, a la infancia y al amor desde un punto de vista científico, psicológico y humano, y te habla de una hormona fundamental, la oxitocina. Un libro que te impulsa a encontrar personas vitamina, aquellas que sacan lo mejor de ti, te inspiran, te apoyan y con ello mejoran tu sistema inmune. Por la autora del bestseller Cómo hacer que te pasen cosas buenas con 350.000 ejemplares vendidos. </span>, <span><br/></span>, <span class="a-text-bold"> ENGLISH DESCRIPTION</span>, <span class="a-text-bold">What is the biochemistry of love? How can we get it right when choosing a partner? Do we love In the way we were loved? </span>, <span>We are designed to live as a family and in society, to interact and to love each other. To a large extent, our happiness will depend on the ability we have to get along with those around us. Many people today carry emotional wounds that prevent them from connecting in a healthy way with their environment. This book will help you understand the bond with your parents, your children, your partner, your friends, and your co-workers, while you understand your emotional history because when you understand yourself, you feel relieved. Dr. Marian Rojas Estapé brings you closer to attachment, childhood, and love from a scientific, psychological, and human point of view, and she talks to you about a fundamental hormone: oxytocin. A book that encourages you to find vitamin people, those who bring out the best in you, inspire you, support you and thereby improve your immune system. </span>]
# ---------------------------------------------------------------------------
# NoSuchWindowException                     Traceback (most recent call last)
# Cell In[21], line 5
#       2 for url in select_row:
#       4     driver.get(url)
# ----> 5     page_content = driver.page_source
#       6     soup = BeautifulSoup(page_content, 'html.parser')
#       9     print(url)
#
# File c:\Users\j50022283\AppData\Local\Programs\Python\Python310\lib\site-packages\selenium\webdriver\remote\webdriver.py:446, in WebDriver.page_source(self)
#     437 @property
#     438 def page_source(self) -> str:
#     439     """Gets the source of the current page.
#     440
#     441     :Usage:
#    (...)
#     444             driver.page_source
#     445     """
# --> 446     return self.execute(Command.GET_PAGE_SOURCE)["value"]
#
# File c:\Users\j50022283\AppData\Local\Programs\Python\Python310\lib\site-packages\selenium\webdriver\remote\webdriver.py:345, in WebDriver.execute(self, driver_command, params)
#     343 response = self.command_executor.execute(driver_command, params)
#     344 if response:
# --> 345     self.error_handler.check_response(response)
#     346     response["value"] = self._unwrap_value(response.get("value", None))
#     347     return response
#
# File c:\Users\j50022283\AppData\Local\Programs\Python\Python310\lib\site-packages\selenium\webdriver\remote\errorhandler.py:229, in ErrorHandler.check_response(self, response)
#     227         alert_text = value["alert"].get("text")
#     228     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 229 raise exception_class(message, screen, stacktrace)
#
# NoSuchWindowException: Message: no such window: target window already closed
# from unknown error: web view not found
#   (Session info: chrome=115.0.5790.171)
# Stacktrace:
# Backtrace:
# 	GetHandleVerifier [0x00007FF715624A62+57106]
# 	(No symbol) [0x00007FF71559CF52]
# 	(No symbol) [0x00007FF71546E2CB]
# 	(No symbol) [0x00007FF71544DEB9]
# 	(No symbol) [0x00007FF7154CAE07]
# 	(No symbol) [0x00007FF7154DDBEF]
# 	(No symbol) [0x00007FF7154C6793]
# 	(No symbol) [0x00007FF71549CE81]
# 	(No symbol) [0x00007FF71549E064]
# 	GetHandleVerifier [0x00007FF7158D4222+2873042]
# 	GetHandleVerifier [0x00007FF715926590+3209792]
# 	GetHandleVerifier [0x00007FF71591F3AF+3180639]
# 	GetHandleVerifier [0x00007FF7156B5F25+652245]
# 	(No symbol) [0x00007FF7155A8618]
# 	(No symbol) [0x00007FF7155A47C4]
# 	(No symbol) [0x00007FF7155A48BC]
# 	(No symbol) [0x00007FF715594C33]
# 	BaseThreadInitThunk [0x00007FF832257614+20]
# 	RtlUserThreadStart [0x00007FF832F626F1+33]
